# %% [markdown]
# <a href="https://colab.research.google.com/github/Eswa2020/hello-world/blob/master/Copy_of_Moringa_Data_Science_Prep_W3_Independent_Project_2020_09_Esther_Kamau_PythonNotebook_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1.0 Import the libraries to be used
# To start off we will download our data.our Data is in excel tables.So for us to read data in python environment that is in excel.We will use Pandas Library.
#
# The following are some of the advantages of the Pandas library:
#
# It can present data in a way that is suitable for data analysis via its Series and DataFrame data structures.
# The package contains multiple methods for convenient data filtering.
# Pandas has a variety of utilities to perform Input/Output operations in a seamless manner.
# It can read data from a variety of formats such as CSV, TSV, MS Excel, etc.

# %% [markdown]
# We will  also  import the numpy library, so that we can leverage external functionalities that do not come with python.
# Numpy arrays are a type of data structures that hold some benefits over
# Python lists such as being more compact, faster access in reading
# And writing items.

# %%
#To use the Panda library we must import it
# Let's import the pandas library just like we did with Numpy
#Let's import the pandas library
# as well as the Numpy library
import pandas as pd

import numpy as np

# %% [markdown]
# #1.1 we load all our datasets
# Pandas is built on the NUmpy package.
# It's main data structure is called DataFrame. Dataframes allows us to store and manipulate data in row and column observations.
# Since our datasets are already in rows and columns it becomes easy to derive them.

# %%
 #We can also load our Excel file as shown below

# We create a URL to Excel file (alternatively this can be a filepath)

#We define our first dataset as url_1
#url='https://github.com/Eswa2020/moringa_school_projects/blob/master/cells_geo_description.xlsx'
url_1='cells_geo_description.xlsx'

# Then load the first sheet of the Excel file into a data frame
df_d2 = pd.read_excel(url_1)
# Lastly, view the first ten rows.
df_d2.head (10)
# Out:
#     Column name        Description  Format
# 0        VILLES               City  String
# 1        STATUS  In Service or not  String
# 2  LOCALISATION  in ABIDJAN or not  String
# 3    DECOUPZONE  Geographical Zone  String
# 4      ZONENAME       Name of Zone  String
# 5     LONGITUDE          Longitude   Float
# 6      LATITUDE           Latitude   Float
# 7        REGION             Region  String
# 8          AREA               Area  String
# 9       CELL_ID     ID of the cell  String

# %%
#We can also load our Excel file as shown below

# We create a URL to Excel file (alternatively this can be a filepath)

#We define our first dataset as url_1

#we add the delimiter to separate the columns since its all jumbled up
#that way we get to know the columns and information in them

url_e='https://raw.githubusercontent.com/Eswa2020/moringa_school_projects/master/cells_geo.csv'
df_t = pd.read_csv(url_e ,delimiter=';',index_col=0)
df_t
# Out:
#         VILLES      STATUS LOCALISATION  ...          AREA     CELL_ID   SITE_CODE
# 0       ADJAME  In Service      ABIDJAN  ...           NaN  fbb2e75af3  0bb492ef17
# 1       ADJAME  In Service      ABIDJAN  ...           NaN  1502501d78  0bb492ef17
# 2       ADJAME  In Service      ABIDJAN  ...           NaN  0c2e182a0c  0bb492ef17
# 3      ASSINIE  In Service    INTERIEUR  ...           NaN  69bdfc69fd  8a1e6ce31f
# 4      ASSINIE  In Service    INTERIEUR  ...           NaN  7a1029d2ab  8a1e6ce31f
# ...        ...         ...          ...  ...           ...         ...         ...
# 3969  ZUENOULA  In Service    INTERIEUR  ...  CENTRE NORTH  1cfc2d7ab1  f91ed8d2e9
# 3970  ZUENOULA  In Service    INTERIEUR  ...  CENTRE NORTH  3ae1708153  f91ed8d2e9
# 3971  ZUENOULA  In Service    INTERIEUR  ...  CENTRE NORTH  cb71f8a29c  61bee9c70c
# 3972  ZUENOULA  In Service    INTERIEUR  ...  CENTRE NORTH  d4a6a0b645  61bee9c70c
# ...

# %%
#url='https://drive.google.com/open?id=1cVoNXl25IO5-_yQk97ThdeqhE6yw8YTD'
url='CDR_description.xlsx'
df_d1=pd.read_excel(url)

df_d1
# Out:
#        Column name                                        Description   Format
# 0          PRODUCT                                       Voice or SMS   String
# 1            VALUE                                      Billing price  Integer
# 2        DATE_TIME               Time in format yyyy-MM-dd hh:mm:ss.0   String
# 3     CELL_ON_SITE  Which cell in the site was used (not needed here)  Integer
# 4  DW_A_NUMBER_INT  Anonymized phone number of the person for whic...   String
# 5  DW_B_NUMBER_INT        Anonymized phone number of the counterparty   String
# 6        COUNTRY_A                  Country of party A (useless here)   String
# 7        COUNTRY_B                  Country of party B (useless here)   String
# 8          CELL_ID                                     ID of the cell   String
# 9          SITE_ID                                     ID of the SITE   String

# %%
url='http://bit.ly/Telcom_dataset1'
df_1=pd.read_csv(url)
df_1
# Out:
#      PRODUTC  VALUE               DATETIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0      Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1        sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2        sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3      Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4      Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4996     sms    100  2012-05-07 00:01:54.0  ...     OTHER  0c2371d9bc  1e751d08a4
# 4997   Voice      1  2012-05-07 00:01:54.0  ...     19e2e  5fb791cf56  65efe2bc62
# 4998   Voice      0  2012-05-07 00:01:54.0  ...     19e2e  7773627c12  9ef9616350
# 4999   Voice      0  2012-05-07 00:01:54.0  ...     19e2e  3f4af49d6c  969b8d0e39
# ...

# %%
url='http://bit.ly/Telcom_dataset2'
#https://github.com/Eswa2020/moringa_school_projects/blob/master/Telcom_dataset2.csv
df_2=pd.read_csv(url)
df_2
# Out:
#      PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0        sms      0  2012-05-07 23:02:06.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 1      Voice      0  2012-05-07 23:03:44.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 2        sms      0  2012-05-07 23:04:06.0  ...     19e2e  +laSrk7g6q  +laSrk7g6q
# 3      Voice     37  2012-05-07 23:04:48.0  ...     19e2e  /xvRrCVKoQ  /xvRrCVKoQ
# 4        sms     25  2012-05-07 23:04:58.0  ...     19e2e  +bO+qkSonO  +bO+qkSonO
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4996     sms      0  2012-05-08 00:01:53.0  ...     19e2e  896459aace  b7d00e59e4
# 4997     sms     25  2012-05-08 00:01:53.0  ...     19e2e  7e90b35166  211015b14d
# 4998     sms      0  2012-05-08 00:01:53.0  ...     19e2e  fe70e431df  c7ea989264
# 4999    data      0  2012-05-08 00:01:53.0  ...     OTHER  ffa6759bb2         NaN
# ...

# %%
url='http://bit.ly/Telcom_dataset3'
#https://github.com/Eswa2020/moringa_school_projects/blob/master/Telcom_dataset3.csv
df_3 = pd.read_csv(url)
df_3
# Out:
#      PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B      CELLID     SIET_ID
# 0      Voice     61  2012-05-08 23:01:28.0  ...     19e2e  +38u2u/rfx  +38u2u/rfx
# 1        sms      0  2012-05-08 23:01:31.0  ...     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2      Voice     10  2012-05-08 23:02:59.0  ...     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3        sms      0  2012-05-08 23:03:04.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4      Voice     22  2012-05-08 23:03:16.0  ...     19e2e  /eeMklgyJA  /eeMklgyJA
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4996   Voice      0  2012-05-09 00:01:43.0  ...     19e2e  2aa04dcab7  f7d63a29e5
# 4997   Voice     62  2012-05-09 00:01:43.0  ...     19e2e  7f1f2f889f  b4ddb9e93c
# 4998   Voice     32  2012-05-09 00:01:43.0  ...     19e2e  a4731e780e  d68260ef50
# 4999   Voice     30  2012-05-09 00:01:43.0  ...     19e2e  98ed726da2  b4130b54ab
# ...

# %% [markdown]
# #1.2 Exploring the data on cell_sites
#
#
#
#
# We will now see how we can filter our datasets by getting the relevant attributes and unique values

# %%
#we will start by exploring our customer data dataset
#our customers dataset we have cells_geo description which we have given variable df_d2
#This is a small data table that just has names of some of the columns in the cells_geo csv.
#The dataset describes the columns of the dataset and in what format they are.
#This data is for us to understand the data more in terms of columns and what datatype  they have
df_d2.head
# Out:
# <bound method NDFrame.head of      Column name                                        Description  Format
# 0         VILLES                                               City  String
# 1         STATUS                                  In Service or not  String
# 2   LOCALISATION                                  in ABIDJAN or not  String
# 3     DECOUPZONE                                  Geographical Zone  String
# 4       ZONENAME                                       Name of Zone  String
# 5      LONGITUDE                                          Longitude   Float
# 6       LATITUDE                                           Latitude   Float
# 7         REGION                                             Region  String
# 8           AREA                                               Area  String
# 9        CELL_ID                                     ID of the cell  String
# 10     SITE_CODE  Site (there are several cells per site, severa...  String>

# %%
#our next dataset is more detailed and we need to select some columns exclusively to have a more indepth exploration
#we will start by printing our data
#we will then select the relevant attributes as depicted in our data report
#3907 rows × 11 columns
df_t=df_t[df_t.STATUS=='In Service']
df_t
#the 3907 rows shows us that 3907 cell-sites are operational
#we should also drop some columns from this table that are unnecessary like a area sicnce we already have our latitudinial and longitudinal positions
#the 'nan" values in status should be replaced with boolean values where "inservice"is replaced by 1 and nan by 0
#also the localisation should also be replaced with interger values for easier analysis and since it has a boolean value we can still replace in abidjan with 1
#not in abidjan with 0
# Out:
#         VILLES      STATUS LOCALISATION  ...          AREA     CELL_ID   SITE_CODE
# 0       ADJAME  In Service      ABIDJAN  ...           NaN  fbb2e75af3  0bb492ef17
# 1       ADJAME  In Service      ABIDJAN  ...           NaN  1502501d78  0bb492ef17
# 2       ADJAME  In Service      ABIDJAN  ...           NaN  0c2e182a0c  0bb492ef17
# 3      ASSINIE  In Service    INTERIEUR  ...           NaN  69bdfc69fd  8a1e6ce31f
# 4      ASSINIE  In Service    INTERIEUR  ...           NaN  7a1029d2ab  8a1e6ce31f
# ...        ...         ...          ...  ...           ...         ...         ...
# 3969  ZUENOULA  In Service    INTERIEUR  ...  CENTRE NORTH  1cfc2d7ab1  f91ed8d2e9
# 3970  ZUENOULA  In Service    INTERIEUR  ...  CENTRE NORTH  3ae1708153  f91ed8d2e9
# 3971  ZUENOULA  In Service    INTERIEUR  ...  CENTRE NORTH  cb71f8a29c  61bee9c70c
# 3972  ZUENOULA  In Service    INTERIEUR  ...  CENTRE NORTH  d4a6a0b645  61bee9c70c
# ...

# %%
#our next dataset is more detailed and we need to select some columns exclusively to have a more indepth exploration
#we will start by printing our data
#we will then select the relevant attributes as depicted in our data report
#67 rows × 11 columns
df_t.Inserv=df_t[df_t.STATUS!='In Service']
df_t.Inserv
#the 67 rows show that only 67 cell_sites are in service
#we can replace inservice with interger values for easy grouping like 0 for nan and 1 for in service
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """
#           VILLES STATUS LOCALISATION  ...           AREA     CELL_ID   SITE_CODE
# 9          ABOBO    NaN      ABIDJAN  ...            NaN  ee224cd27e  56306cc7ca
# 10         ABOBO    NaN      ABIDJAN  ...            NaN  107d0d752c  56306cc7ca
# 164   BONGOUANOU    NaN    INTERIEUR  ...  ABIDJAN SOUTH  6750e0fb7b  20387d4292
# 183   BONGOUANOU    NaN    INTERIEUR  ...           EAST  6750e0fb7b  20387d4292
# 184   BONGOUANOU    NaN    INTERIEUR  ...           EAST  6750e0fb7b  20387d4292
# ...          ...    ...          ...  ...            ...         ...         ...
# 3691      ADJAME    NaN      ABIDJAN  ...  ABIDJAN NORTH  b0dbc2e61c  5c565fbfb1
# 3804    YOPOUGON    NaN      ABIDJAN  ...  ABIDJAN NORTH  6680e8a299  2d58cad870
# ...

# %%
#To view the column lacalization so as to know apart from abidjan which are the other options
#We get to know all the other  cities that have cell_sites
#We Would run the following but this would only give duplicates
#so we  go ahead and get the unique values in VILLES 
#We can list them by using the following or just create an array like below
#list(set(df_t.VILLES))
(df_t['VILLES'].unique())
#the column villes has very many unique values 
#it can help us group  places with cities and know them
# Out:
# array(['ADJAME', 'ASSINIE', 'KRIKOREA', 'ABOBO', 'BINGERVILLE', 'PLATEAU',
#        'DALOA', 'ABENGOUROU', 'ATTECOUBE', 'ABOISSO COMOE', 'ABOISSO',
#        'BONGOUANOU', 'ABONGOUA', 'ABOUDEKOUASSIKRO', 'ABRONAMOUE',
#        'YOPOUGON', 'ADAOU', 'ADDAH', 'ADEBEM', 'ADIAKE', 'ADJAMENE',
#        'PORT-BOUET', 'ADZOPE', 'AFFERY', 'COCODY', 'AGBOVILLE',
#        'AGNIBILEKRO', 'AGONDA', 'AGOU', 'MARCORY', 'AHIZABRO', 'AHOUANOU',
#        'BOUAKE', 'AKOBOISSUE', 'AKOUPE', 'AKOUYAKRO', 'AKRADJO',
#        'KOUMASSI', 'ALEPE', 'ALERIA', 'BAMORO', 'ALLOKOI', 'ANANDA',
#        'ANDO', 'ANDOKOKRENOU', 'ANIANSUE', 'ANOUMABA', 'ANYAMA',
#        'AOUNIANFOUTOU', 'APPOISSO', 'ARRAH', 'ASSIKOI', 'ASSUEFRY',
#        'ATTIGUEHI', 'ATTINGUIE', 'ATTROBROU', 'AYAME', 'AYAPRIKRO',
#        'AZAGUIE', 'BACANDA', 'BADIKAHA', 'BAGOHOUO', 'BAHOMPA',
#        'BACOUBLY', 'BALEKO', 'SAN-PEDRO', 'BANADJE', 'BANANKORO',
#        'BANDAKANY', 'BANDIAHI', 'BANGOLO', 'BANIA', 'BANTEAPLEU',
# ...

# %%
#We run cell_id since they are very unique values and group them by site_code to know if we can do this 
#we run with to the cell_id grouped by site_code
mycols1=['CELL_ID','SITE_CODE']
df_t[mycols1].groupby(df_t['SITE_CODE'])
df_t[mycols1].head(50 )
#from the below results we can see that site_id can be used to groupd cell_id since they have very unique values
# Out:
#        CELL_ID   SITE_CODE
# 0   fbb2e75af3  0bb492ef17
# 1   1502501d78  0bb492ef17
# 2   0c2e182a0c  0bb492ef17
# 3   69bdfc69fd  8a1e6ce31f
# 4   7a1029d2ab  8a1e6ce31f
# 5   0b4f56438f  8a1e6ce31f
# 6   041d2504f5  260dbfedc5
# 7   a70c1d263b  56306cc7ca
# 8   e2d04ea883  56306cc7ca
# 9   ee224cd27e  56306cc7ca
# 10  107d0d752c  56306cc7ca
# 11  3f766cedc0  c1ccd3443b
# 12  b0578cdb7f  c1ccd3443b
# 13  18a4221316  c1ccd3443b
# 14  1b2bccad1f  c1ccd3443b
# 15  60865ff87f  17899e217a
# 16  c1dc258dc9  17899e217a
# 17  377ee76a7e  17899e217a
# 18  46185e38ee  aaca2668a7
# 19  ddb6bc11df  aaca2668a7
# 20  c4d2b0444b  aaca2668a7
# 21  fa307adc83  92d827bd96
# 22  4ddfebaf66  92d827bd96
# 23  f740406877  0f34c36ac5
# 24  959e54c8f7  0f34c36ac5
# 25  56b7e7000c  0f34c36ac5
# 26  bc51c17a6f  0f34c36ac5
# 27  e460975c9f  0f34c36ac5
# 28  2d125e9a95  0f34c36ac5
# 29  7cf207ef76  7430461f18
# 30  49377d7ad6  7430461f18
# 31  558c31e1a6  7430461f18
# 32  6a7a3aeebe  7430461f18
# ...

# %%
#To get the contents of array site_code 
#we use the.unique function
#to view it we run
list(df_t['SITE_CODE'].unique())
#our site_codes also has very many unique values
# Out:
# ['0bb492ef17',
#  '8a1e6ce31f',
#  '260dbfedc5',
#  '56306cc7ca',
#  'c1ccd3443b',
#  '17899e217a',
#  'aaca2668a7',
#  '92d827bd96',
#  '0f34c36ac5',
#  '7430461f18',
#  'ed2333b820',
#  '06c4cb622d',
#  '6e87d6cb59',
#  'aa2d7103fc',
#  '00197a4f5f',
#  '547385b9d5',
#  '40cb5c4468',
#  '4df1cab780',
#  '8117043112',
#  '2371f0c1df',
#  '70a989da87',
#  '1c5e6fb08e',
#  'ad67d8727e',
#  'd4b46cdec7',
#  '7bb5edf329',
#  '651c6d67d4',
#  '46f254f80c',
#  '50141ace80',
#  'f56286a418',
#  'c1ec9c885f',
#  'e7f9159de4',
#  'a3efd45afb',
#  '2dd67b6a64',
#  '73974f7f81',
#  '59a53648cd',
#  'ef51d8b174',
#  '640427c4c9',
#  '38c5c1de07',
#  '20387d4292',
#  'ac3b6998ac',
#  'd52bb03161',
#  'a8d8462dda',
#  'c99c8fb224',
#  '6cdf1d4b52',
#  'd24a387c10',
#  'ef3841e458',
#  '1ed7b897b7',
#  '331d88bd21',
#  'ce4fd4068e',
#  'dd656c150a',
#  '32e88e3bb2',
#  '81f4c462f7',
#  'ec2f249b2b',
#  '7ec8f9bb0e',
#  '464083a6c2',
#  'f191951c20',
#  '16d3b44b2d',
#  'aa4edfa221',
# ...

# %%
#since these arrays are to unique for grouping we check otheR COLUMNS 
#the row for localisation only has abidjan and not in abidjan
#we will first view the sites that are in abidjan
#abidjan_sites 
#1669 rows × 12 columns
df_t.abidjan_sites=df_t[df_t.LOCALISATION == 'ABIDJAN']
df_t.abidjan_sites
#only 1669 sites in abidjan
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   This is separate from the ipykernel package so we can avoid doing imports until
#       Unnamed: 0   VILLES      STATUS  ...           AREA     CELL_ID   SITE_CODE
# 0              0   ADJAME  In Service  ...            NaN  fbb2e75af3  0bb492ef17
# 1              1   ADJAME  In Service  ...            NaN  1502501d78  0bb492ef17
# 2              2   ADJAME  In Service  ...            NaN  0c2e182a0c  0bb492ef17
# 7              7    ABOBO  In Service  ...            NaN  a70c1d263b  56306cc7ca
# 8              8    ABOBO  In Service  ...            NaN  e2d04ea883  56306cc7ca
# ...          ...      ...         ...  ...            ...         ...         ...
# 3957        3957  MARCORY  In Service  ...  ABIDJAN SOUTH  32dbfb021a  1ff98189c8
# ...

# %%
#we will first view the sites that are  in abidjan AND are in service
#we will name them df_abidserv
#1636 rows × 11 columns
df_abidserv=df_t[(df_t['LOCALISATION'] == 'ABIDJAN') & (df_t['STATUS'] == 'In Service')]

df_abidserv
#only 1636  out of the 1669 sites are in service
# Out:
#        VILLES      STATUS LOCALISATION  ...           AREA     CELL_ID   SITE_CODE
# 0      ADJAME  In Service      ABIDJAN  ...            NaN  fbb2e75af3  0bb492ef17
# 1      ADJAME  In Service      ABIDJAN  ...            NaN  1502501d78  0bb492ef17
# 2      ADJAME  In Service      ABIDJAN  ...            NaN  0c2e182a0c  0bb492ef17
# 7       ABOBO  In Service      ABIDJAN  ...            NaN  a70c1d263b  56306cc7ca
# 8       ABOBO  In Service      ABIDJAN  ...            NaN  e2d04ea883  56306cc7ca
# ...       ...         ...          ...  ...            ...         ...         ...
# 3957  MARCORY  In Service      ABIDJAN  ...  ABIDJAN SOUTH  32dbfb021a  1ff98189c8
# 3958  MARCORY  In Service      ABIDJAN  ...  ABIDJAN SOUTH  71d9ff904d  1ff98189c8
# 3959  MARCORY  In Service      ABIDJAN  ...  ABIDJAN SOUTH  bbdd523132  1ff98189c8
# 3966  MARCORY  In Service      ABIDJAN  ...  ABIDJAN SOUTH  eb76e06e8e  6daf54117b
# ...

# %%
#we will first view the sites that are  in  NOT IN abidjan BUT ARE IN  in service
#we will name them df_abidservS
#2271 rows × 11 columns
df_abidservS=df_t[~(df_t['LOCALISATION'] == 'ABIDJAN') & (df_t['STATUS'] == 'In Service')]
df_abidservS
#2271 site that are not in abidjan are in service
# Out:
#         VILLES      STATUS LOCALISATION  ...          AREA     CELL_ID   SITE_CODE
# 3      ASSINIE  In Service    INTERIEUR  ...           NaN  69bdfc69fd  8a1e6ce31f
# 4      ASSINIE  In Service    INTERIEUR  ...           NaN  7a1029d2ab  8a1e6ce31f
# 5      ASSINIE  In Service    INTERIEUR  ...           NaN  0b4f56438f  8a1e6ce31f
# 6     KRIKOREA  In Service    INTERIEUR  ...           NaN  041d2504f5  260dbfedc5
# 38       DALOA  In Service    INTERIEUR  ...    NORTH WEST  d133371158  06c4cb622d
# ...        ...         ...          ...  ...           ...         ...         ...
# 3969  ZUENOULA  In Service    INTERIEUR  ...  CENTRE NORTH  1cfc2d7ab1  f91ed8d2e9
# 3970  ZUENOULA  In Service    INTERIEUR  ...  CENTRE NORTH  3ae1708153  f91ed8d2e9
# 3971  ZUENOULA  In Service    INTERIEUR  ...  CENTRE NORTH  cb71f8a29c  61bee9c70c
# 3972  ZUENOULA  In Service    INTERIEUR  ...  CENTRE NORTH  d4a6a0b645  61bee9c70c
# ...

# %%
#we will first view THE sites that are  in  NOT IN abidjan BUT ARE NOT  in service
#we will name them df_abidservS
#2271 rows × 11 columns
df_abidservN=df_t[~(df_t['LOCALISATION'] == 'ABIDJAN') & (df_t['STATUS'] != 'In Service')]
df_abidservN
#from this we can observe most cities that are not in abidjan and are not in sevice are in a city called bongouanou
# Out:
#           VILLES STATUS LOCALISATION  ...           AREA     CELL_ID   SITE_CODE
# 164   BONGOUANOU    NaN    INTERIEUR  ...  ABIDJAN SOUTH  6750e0fb7b  20387d4292
# 183   BONGOUANOU    NaN    INTERIEUR  ...           EAST  6750e0fb7b  20387d4292
# 184   BONGOUANOU    NaN    INTERIEUR  ...           EAST  6750e0fb7b  20387d4292
# 185   BONGOUANOU    NaN    INTERIEUR  ...           EAST  6750e0fb7b  20387d4292
# 573   BONGOUANOU    NaN    INTERIEUR  ...  ABIDJAN SOUTH  6750e0fb7b  20387d4292
# 574   BONGOUANOU    NaN    INTERIEUR  ...  ABIDJAN SOUTH  6750e0fb7b  20387d4292
# 575   BONGOUANOU    NaN    INTERIEUR  ...  ABIDJAN SOUTH  6750e0fb7b  20387d4292
# 727   BONGOUANOU    NaN    INTERIEUR  ...           EAST  6750e0fb7b  20387d4292
# 890   BONGOUANOU    NaN    INTERIEUR  ...           EAST  6750e0fb7b  20387d4292
# 1206  BONGOUANOU    NaN    INTERIEUR  ...     NORTH WEST  6750e0fb7b  20387d4292
# 1207  BONGOUANOU    NaN    INTERIEUR  ...     NORTH WEST  6750e0fb7b  20387d4292
# ...

# %%
#from this we can also derive to know the cities that are not in abidjan
#2305 × 11columns
df_t.abid_sites=df_t[df_t.LOCALISATION == 'INTERIEUR']
df_t.abid_sites
#only 2305 sites in  OUTSIDE abidjan
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   This is separate from the ipykernel package so we can avoid doing imports until
#         VILLES      STATUS LOCALISATION  ...          AREA     CELL_ID   SITE_CODE
# 3      ASSINIE  In Service    INTERIEUR  ...           NaN  69bdfc69fd  8a1e6ce31f
# 4      ASSINIE  In Service    INTERIEUR  ...           NaN  7a1029d2ab  8a1e6ce31f
# 5      ASSINIE  In Service    INTERIEUR  ...           NaN  0b4f56438f  8a1e6ce31f
# 6     KRIKOREA  In Service    INTERIEUR  ...           NaN  041d2504f5  260dbfedc5
# 38       DALOA  In Service    INTERIEUR  ...    NORTH WEST  d133371158  06c4cb622d
# ...        ...         ...          ...  ...           ...         ...         ...
# 3969  ZUENOULA  In Service    INTERIEUR  ...  CENTRE NORTH  1cfc2d7ab1  f91ed8d2e9
# ...

# %%
#we will first view THE sites that are  in  NOT IN abidjan  ARE  in service
#we will name them df_abidserN
#1636 rows × 11 columns
df_abidserN=df_t[~(df_t['LOCALISATION'] == 'INTERIEUR') & (df_t['STATUS'] == 'In Service')]
df_abidserN
#OUT OF THE 2305 ONLY 1636 SITES ARE IN SERVICE
# Out:
#        VILLES      STATUS LOCALISATION  ...           AREA     CELL_ID   SITE_CODE
# 0      ADJAME  In Service      ABIDJAN  ...            NaN  fbb2e75af3  0bb492ef17
# 1      ADJAME  In Service      ABIDJAN  ...            NaN  1502501d78  0bb492ef17
# 2      ADJAME  In Service      ABIDJAN  ...            NaN  0c2e182a0c  0bb492ef17
# 7       ABOBO  In Service      ABIDJAN  ...            NaN  a70c1d263b  56306cc7ca
# 8       ABOBO  In Service      ABIDJAN  ...            NaN  e2d04ea883  56306cc7ca
# ...       ...         ...          ...  ...            ...         ...         ...
# 3957  MARCORY  In Service      ABIDJAN  ...  ABIDJAN SOUTH  32dbfb021a  1ff98189c8
# 3958  MARCORY  In Service      ABIDJAN  ...  ABIDJAN SOUTH  71d9ff904d  1ff98189c8
# 3959  MARCORY  In Service      ABIDJAN  ...  ABIDJAN SOUTH  bbdd523132  1ff98189c8
# 3966  MARCORY  In Service      ABIDJAN  ...  ABIDJAN SOUTH  eb76e06e8e  6daf54117b
# ...

# %%
#We run cell_id since they are very unique values and group them by site_code to know if we can do this 
#we run with to the cell_id grouped by site_code
mycols2=['VILLES','STATUS']
df_t[mycols2].groupby(df_t['STATUS'])
df_t[mycols2].head(100 )
#from the below results we can see that site_id can be used to groupd cell_id since they have very unique values
# Out:
#      VILLES      STATUS
# 0    ADJAME  In Service
# 1    ADJAME  In Service
# 2    ADJAME  In Service
# 3   ASSINIE  In Service
# 4   ASSINIE  In Service
# ..      ...         ...
# 95    ABOBO  In Service
# 96    ABOBO  In Service
# 97    ABOBO  In Service
# 98    ABOBO  In Service
# 99    ABOBO  In Service
#
# [100 rows x 2 columns]

# %% [markdown]
# # 1.3 Exploring data on customers from tableset1,tablese2 & tableset3

# %%
#our next dataset is explains more about our clients customers and which cell_site they using
#we will knowing ou products and value our products
#we will then select the relevant attributes as depicted in our data report
#2219 rows × 11 columns
df_1[df_1.PRODUTC=='Voice']
df_1.voice
#There are 2219 voice products out of 5001 from table set 1
#the name for product has been spelled wrongly we need to correct it and column datetime
#also we need to drop column,cell on site,countya,countryb, since they are of no use to our project
#we need to sort our dates time in ascending order
#we will run codes for table dataset1,dataset2,dataset3 just to explore
#after the drop of irrelevant columns and correcting out table we can the three correct tables to make the analysis very easy
#we will go extra step of  still merging our new table with the necessary columns from  the cell sites database
# Out:
#      PRODUTC  VALUE               DATETIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0      Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 3      Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4      Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
# 6      Voice      0  2012-05-06 23:08:02.0  ...     19e2e  +38u2u/rfx  +38u2u/rfx
# 7      Voice      0  2012-05-06 23:08:03.0  ...     19e2e  09UjmmY1Ds  09UjmmY1Ds
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4979   Voice      7  2012-05-07 00:01:53.0  ...     19e2e  4a71bcb73f  e1a3687210
# 4997   Voice      1  2012-05-07 00:01:54.0  ...     19e2e  5fb791cf56  65efe2bc62
# 4998   Voice      0  2012-05-07 00:01:54.0  ...     19e2e  7773627c12  9ef9616350
# 4999   Voice      0  2012-05-07 00:01:54.0  ...     19e2e  3f4af49d6c  969b8d0e39
# ...

# %%
df_2[df_2.PRODUCT=='Voice']
df_2.voice
#1906 rows × 10 columns
#This means out of 5001 records dataset 2 has 1906 records for voice
#APART from that all our columns have been nemed correctly and well
#just like one we need to drop the unnecessary columns thas countrya,countryb,and cell on site
# Out:
#      PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 1      Voice      0  2012-05-07 23:03:44.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 3      Voice     37  2012-05-07 23:04:48.0  ...     19e2e  /xvRrCVKoQ  /xvRrCVKoQ
# 6      Voice     41  2012-05-07 23:06:14.0  ...     19e2e  +laSrk7g6q  +laSrk7g6q
# 7      Voice     11  2012-05-07 23:06:28.0  ...     19e2e  +gySf02tKW  +gySf02tKW
# 18     Voice      0  2012-05-07 23:08:16.0  ...     19e2e  /0LopuZdd7  /0LopuZdd7
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4977   Voice     19  2012-05-08 00:01:53.0  ...     19e2e  ffb86d66d2  4df1cab780
# 4978   Voice    158  2012-05-08 00:01:53.0  ...     19e2e  ed472df66d  f3a6b6efd1
# 4981   Voice      2  2012-05-08 00:01:53.0  ...     19e2e  32fcb79772  244bc13af3
# 4982   Voice    405  2012-05-08 00:01:53.0  ...     19e2e  7ce0e70ac0  35cae15a08
# ...

# %%
df_3[df_3.PRODUCT=='Voice']
df_3.voice
#1541 rows × 10 columns
#This means out of 5001 records dataset 2 has 1541 records for voice
#APART from that all our columns have been nemed correctly except fro cell id and site id columns
#just like one we need to drop the unnecessary columns thas countrya,countryb,and cell on site
# Out:
#      PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B      CELLID     SIET_ID
# 0      Voice     61  2012-05-08 23:01:28.0  ...     19e2e  +38u2u/rfx  +38u2u/rfx
# 2      Voice     10  2012-05-08 23:02:59.0  ...     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 4      Voice     22  2012-05-08 23:03:16.0  ...     19e2e  /eeMklgyJA  /eeMklgyJA
# 5      Voice     10  2012-05-08 23:03:59.0  ...     19e2e  +e+xcimwre  +e+xcimwre
# 7      Voice     10  2012-05-08 23:06:55.0  ...     19e2e  +ZaaZozy/+  +ZaaZozy/+
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4996   Voice      0  2012-05-09 00:01:43.0  ...     19e2e  2aa04dcab7  f7d63a29e5
# 4997   Voice     62  2012-05-09 00:01:43.0  ...     19e2e  7f1f2f889f  b4ddb9e93c
# 4998   Voice     32  2012-05-09 00:01:43.0  ...     19e2e  a4731e780e  d68260ef50
# 4999   Voice     30  2012-05-09 00:01:43.0  ...     19e2e  98ed726da2  b4130b54ab
# ...

# %% [markdown]
# #2.0 Selecting and sorting data on customers table 1

# %%
#we will first start by changing column name that is wrong produtc to product
#then we will proceed to change the products voice and sms to interger values that will make it easy for us to do analysis
#we will also arrange our date and times in ascending orders
#by adding inplace is true changes this order permanently
df_1.sort_values(by=['DATETIME'],inplace=True, ascending=True)
df_1
#this helps us know our dates well this table  entry is from 06/05/12(2304hrs) to 07/05/12(00154hrs)
#in a span of 24hours our cells are capturing 5000 engagements
#next we will replace our column produtc to product
df_1.rename(columns = {'PRODUTC':'PRODUCT'}, inplace = True)
df_1
#we also want to replace our column product values to voice=1,and sms=0
df_1['PRODUCT']=df_1.replace(to_replace="sms",value="2")
df_1
#then we replace voice
df_1['PRODUCT']=df_1.replace(to_replace='Voice',value="1")
df_1
# Out:
#      PRODUCT  VALUE               DATETIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0          1      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1          2      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2          2     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3          1     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4          1     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4990       2      0  2012-05-07 00:01:54.0  ...     19e2e  0cc4fd600e  e04667f9c7
# 4988       2      0  2012-05-07 00:01:54.0  ...     19e2e  d22224b2fa  2d58cad870
# 4999       1      0  2012-05-07 00:01:54.0  ...     19e2e  3f4af49d6c  969b8d0e39
# 4993       2     50  2012-05-07 00:01:54.0  ...     19e2e  babc0339bd  13c690c436
# ...

# %% [markdown]
# # 2.1 Selecting and sorting data on customers table 2

# %%
#we will first start by changing column name that is wrong 'date_time' with 'datetime' to product
#then we will proceed to change the products voice and sms to interger values that will make it easy for us to do analysis
#we will also arrange our date and times in ascending orders
#by adding inplace is true changes this order permanently
#df_2.sort_values(by=['DATE_TIME'],inplace=True, ascending=True)
#df_2
#this helps us know our dates well this table  entry is from 07/05/12(2303hrs) to 08/05/12(00153hrs)
#we will replace our date_time to correpond to the first table
df_2.rename(columns = {'DATE_TIME':'DATETIME'}, inplace = True)
df_2
#next we change the column product's values to attributable but interger values where voice=1 ans sms=2
#we also want to replace our column product values to voice=1,and sms=0
df_2['PRODUCT']=df_2.replace(to_replace="sms",value="2")
df_2
#then we replace voice
df_2['PRODUCT']=df_2.replace(to_replace='Voice',value="1")
df_2
# Out:
#      PRODUCT  VALUE               DATETIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0          2      0  2012-05-07 23:02:06.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 1          1      0  2012-05-07 23:03:44.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 2          2      0  2012-05-07 23:04:06.0  ...     19e2e  +laSrk7g6q  +laSrk7g6q
# 3          1     37  2012-05-07 23:04:48.0  ...     19e2e  /xvRrCVKoQ  /xvRrCVKoQ
# 4          2     25  2012-05-07 23:04:58.0  ...     19e2e  +bO+qkSonO  +bO+qkSonO
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4996       2      0  2012-05-08 00:01:53.0  ...     19e2e  896459aace  b7d00e59e4
# 4997       2     25  2012-05-08 00:01:53.0  ...     19e2e  7e90b35166  211015b14d
# 4998       2      0  2012-05-08 00:01:53.0  ...     19e2e  fe70e431df  c7ea989264
# 4999    data      0  2012-05-08 00:01:53.0  ...     OTHER  ffa6759bb2         NaN
# ...

# %% [markdown]
# # 2.2 Selecting and sorting data on customers table 3

# %%
#we will change 3 columns datetime,cell id, and site id
#then we will proceed to change the products voice and sms to interger values that will make it easy for us to do analysis
#we will also arrange our date and times in ascending orders
#by adding inplace is true changes this order permanently
#df_3.sort_values(by=['DATE_TIME'],inplace=True, ascending=True)
#df_3
#this helps us know our dates well this table  entry is from 08/05/12(2301hrs) to 09/05/12(00143hrs)
#we will change 3 columns datetime,cell id, and site id
df_3.rename(columns = {'DATE_TIME':'DATETIME','CELLID':'CELL_ID','SIET_ID':'SITE_ID'}, inplace = True)
df_3
#we also want to replace our column product values to voice=1,and sms=0
df_3['PRODUCT']=df_3.replace(to_replace="sms",value="2")
df_3
#then we replace voice
df_3['PRODUCT']=df_3.replace(to_replace='Voice',value="1")
df_3
# Out:
#      PRODUCT  VALUE               DATETIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0          1     61  2012-05-08 23:01:28.0  ...     19e2e  +38u2u/rfx  +38u2u/rfx
# 1          2      0  2012-05-08 23:01:31.0  ...     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2          1     10  2012-05-08 23:02:59.0  ...     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3          2      0  2012-05-08 23:03:04.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4          1     22  2012-05-08 23:03:16.0  ...     19e2e  /eeMklgyJA  /eeMklgyJA
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4996       1      0  2012-05-09 00:01:43.0  ...     19e2e  2aa04dcab7  f7d63a29e5
# 4997       1     62  2012-05-09 00:01:43.0  ...     19e2e  7f1f2f889f  b4ddb9e93c
# 4998       1     32  2012-05-09 00:01:43.0  ...     19e2e  a4731e780e  d68260ef50
# 4999       1     30  2012-05-09 00:01:43.0  ...     19e2e  98ed726da2  b4130b54ab
# ...

# %% [markdown]
# #2.4 selecting and sorting data on cell_sites  table

# %%
#we will first start by changing column name 'site code' to 'site id ' so that when merging the names are the same
df_t.rename(columns = {'SITE_CODE':'SITE_ID','VILLES':'CITIES','LOCALISATION':'LOCALS'}, inplace = True)
df_t
# Out:
#         CITIES      STATUS     LOCALS  ...          AREA     CELL_ID     SITE_ID
# 0       ADJAME  In Service    ABIDJAN  ...           NaN  fbb2e75af3  0bb492ef17
# 1       ADJAME  In Service    ABIDJAN  ...           NaN  1502501d78  0bb492ef17
# 2       ADJAME  In Service    ABIDJAN  ...           NaN  0c2e182a0c  0bb492ef17
# 3      ASSINIE  In Service  INTERIEUR  ...           NaN  69bdfc69fd  8a1e6ce31f
# 4      ASSINIE  In Service  INTERIEUR  ...           NaN  7a1029d2ab  8a1e6ce31f
# ...        ...         ...        ...  ...           ...         ...         ...
# 3969  ZUENOULA  In Service  INTERIEUR  ...  CENTRE NORTH  1cfc2d7ab1  f91ed8d2e9
# 3970  ZUENOULA  In Service  INTERIEUR  ...  CENTRE NORTH  3ae1708153  f91ed8d2e9
# 3971  ZUENOULA  In Service  INTERIEUR  ...  CENTRE NORTH  cb71f8a29c  61bee9c70c
# 3972  ZUENOULA  In Service  INTERIEUR  ...  CENTRE NORTH  d4a6a0b645  61bee9c70c
# 3973  ZUENOULA  In Service  INTERIEUR  ...  CENTRE NORTH  f9f3e42589  61bee9c70c
#
# ...

# %%
#then we will proceed to change the column values for status to 1 and 0 where inservice=1 and not =0
#we will also change column values for local where abidjan=1 and not in abidjan=2
#Masks are ’Boolean’ arrays – that is arrays of true and false values and provide a powerful and flexible method to selecting data.
#since our column values are already in boolean we will use this mask for this
df_t['STATUS'].mask(df_t['STATUS'] == 'In Service', '1', inplace=True)
df_t
#to nnow mask the status that WAS NOT INSERVICE WE CAN USE 'WHERE'
#m = df_t.STATUS != 'In Service'
#df_t.where(~m,other='1')
#d_f_t.head(50)
# Out:
#         CITIES STATUS     LOCALS  ...          AREA     CELL_ID     SITE_ID
# 0       ADJAME      1    ABIDJAN  ...           NaN  fbb2e75af3  0bb492ef17
# 1       ADJAME      1    ABIDJAN  ...           NaN  1502501d78  0bb492ef17
# 2       ADJAME      1    ABIDJAN  ...           NaN  0c2e182a0c  0bb492ef17
# 3      ASSINIE      1  INTERIEUR  ...           NaN  69bdfc69fd  8a1e6ce31f
# 4      ASSINIE      1  INTERIEUR  ...           NaN  7a1029d2ab  8a1e6ce31f
# ...        ...    ...        ...  ...           ...         ...         ...
# 3969  ZUENOULA      1  INTERIEUR  ...  CENTRE NORTH  1cfc2d7ab1  f91ed8d2e9
# 3970  ZUENOULA      1  INTERIEUR  ...  CENTRE NORTH  3ae1708153  f91ed8d2e9
# 3971  ZUENOULA      1  INTERIEUR  ...  CENTRE NORTH  cb71f8a29c  61bee9c70c
# 3972  ZUENOULA      1  INTERIEUR  ...  CENTRE NORTH  d4a6a0b645  61bee9c70c
# 3973  ZUENOULA      1  INTERIEUR  ...  CENTRE NORTH  f9f3e42589  61bee9c70c
#
# [3974 rows x 11 columns]

# %% [markdown]
# # 2.5droppping columns in customer details dataset 1,2,& 3

# %%
#we can drop the columns not relevant to our study
#we will start with our customer tables
#we will drop,'cell_on site','countrya','countryb'..they all useless to our study
#Pandas’ drop function can be used to drop multiple columns as well. 
#To drop or remove multiple columns, one simply needs to give all the names of columns that we want to drop as a list
df_1d=df_1.drop(['CELL_ON_SITE', 'COUNTRY_A', 'COUNTRY_B'], axis=1)
df_1d
# Out:
#      PRODUCT  VALUE  ...     CELL_ID     SITE_ID
# 0          1      0  ...  /TJNe+Mmtu  /TJNe+Mmtu
# 1          2      0  ...  /+cKZKIp41  /+cKZKIp41
# 2          2     25  ...  /u0FSD+ahi  /u0FSD+ahi
# 3          1     56  ...  +cNeJzsTp3  +cNeJzsTp3
# 4          1     14  ...  051KhYDCpv  051KhYDCpv
# ...      ...    ...  ...         ...         ...
# 4990       2      0  ...  0cc4fd600e  e04667f9c7
# 4988       2      0  ...  d22224b2fa  2d58cad870
# 4999       1      0  ...  3f4af49d6c  969b8d0e39
# 4993       2     50  ...  babc0339bd  13c690c436
# 5000       1      7  ...  6f4d9b77a5  ebfc58af70
#
# [5001 rows x 7 columns]

# %%
#we can drop the columns not relevant to our study
#we will start with our customer tables
#we will drop,'cell_on site','countrya','countryb'..they all useless to our study
#Pandas’ drop function can be used to drop multiple columns as well. 
#To drop or remove multiple columns, one simply needs to give all the names of columns that we want to drop as a list
df_2d=df_2.drop(['CELL_ON_SITE', 'COUNTRY_A', 'COUNTRY_B'], axis=1)
df_2d
# Out:
#      PRODUCT  VALUE  ...     CELL_ID     SITE_ID
# 0          2      0  ...  +854AcBQT2  +854AcBQT2
# 1          1      0  ...  +854AcBQT2  +854AcBQT2
# 2          2      0  ...  +laSrk7g6q  +laSrk7g6q
# 3          1     37  ...  /xvRrCVKoQ  /xvRrCVKoQ
# 4          2     25  ...  +bO+qkSonO  +bO+qkSonO
# ...      ...    ...  ...         ...         ...
# 4996       2      0  ...  896459aace  b7d00e59e4
# 4997       2     25  ...  7e90b35166  211015b14d
# 4998       2      0  ...  fe70e431df  c7ea989264
# 4999    data      0  ...  ffa6759bb2         NaN
# 5000       1      0  ...  8630058aca  b47a998a3e
#
# [5001 rows x 7 columns]

# %%
#we can drop the columns not relevant to our study
#we will start with our customer tables
#we will drop,'cell_on site','countrya','countryb'..they all useless to our study
#Pandas’ drop function can be used to drop multiple columns as well. 
#To drop or remove multiple columns, one simply needs to give all the names of columns that we want to drop as a list
df_3d=df_3.drop(['CELL_ON_SITE', 'COUNTRY_A', 'COUNTRY_B'], axis=1)
df_3d
# Out:
#      PRODUCT  VALUE  ...     CELL_ID     SITE_ID
# 0          1     61  ...  +38u2u/rfx  +38u2u/rfx
# 1          2      0  ...  +Fs4mTvdKx  +Fs4mTvdKx
# 2          1     10  ...  +ZaaZozy/+  +ZaaZozy/+
# 3          2      0  ...  +cNeJzsTp3  +cNeJzsTp3
# 4          1     22  ...  /eeMklgyJA  /eeMklgyJA
# ...      ...    ...  ...         ...         ...
# 4996       1      0  ...  2aa04dcab7  f7d63a29e5
# 4997       1     62  ...  7f1f2f889f  b4ddb9e93c
# 4998       1     32  ...  a4731e780e  d68260ef50
# 4999       1     30  ...  98ed726da2  b4130b54ab
# 5000       1     60  ...  1c11a2fcbb  6d70dae094
#
# [5001 rows x 7 columns]

# %% [markdown]
# #3.1 merging the customers tables

# %%
#we will use concat()function because out datsets have the columns with same information
#we will use the datasets above after the drop.
#To simply concatenate the DataFrames along the row you can use the concat() function in pandas.
#You will have to pass the names of the DataFrames in a list as the argument to the concat() function:
#Mentioning the keys also makes it easy to retrieve data corresponding to a particular DataFrame.
#our keyd in this instance is x,y,z

pieces = {'x': df_1d, 'y': df_2d,'z':df_3d}

df_piece = pd.concat(pieces)

df_piece
# Out:
#        PRODUCT  VALUE  ... DW_A_NUMBER DW_B_NUMBER
# x 0          1      0  ...         NaN         NaN
#   1          2      0  ...         NaN         NaN
#   2          2     25  ...         NaN         NaN
#   3          1     56  ...         NaN         NaN
#   4          1     14  ...         NaN         NaN
# ...        ...    ...  ...         ...         ...
# z 4996       1      0  ...         NaN         NaN
#   4997       1     62  ...         NaN         NaN
#   4998       1     32  ...         NaN         NaN
#   4999       1     30  ...         NaN         NaN
#   5000       1     60  ...         NaN         NaN
#
# [15003 rows x 9 columns]

# %%
#we first had to drop the unnecessary informationin this too
#and since we have latitudinal and longidunial positions we drop columns
#'decoup','zonename,'region','area'
df_4D=df_piece.drop(['DW_A_NUMBER', 'DW_B_NUMBER'], axis=1)
df_4D
# Out:
#        PRODUCT  VALUE  ...     CELL_ID     SITE_ID
# x 0          1      0  ...  /TJNe+Mmtu  /TJNe+Mmtu
#   1          2      0  ...  /+cKZKIp41  /+cKZKIp41
#   2          2     25  ...  /u0FSD+ahi  /u0FSD+ahi
#   3          1     56  ...  +cNeJzsTp3  +cNeJzsTp3
#   4          1     14  ...  051KhYDCpv  051KhYDCpv
# ...        ...    ...  ...         ...         ...
# z 4996       1      0  ...  2aa04dcab7  f7d63a29e5
#   4997       1     62  ...  7f1f2f889f  b4ddb9e93c
#   4998       1     32  ...  a4731e780e  d68260ef50
#   4999       1     30  ...  98ed726da2  b4130b54ab
#   5000       1     60  ...  1c11a2fcbb  6d70dae094
#
# [15003 rows x 7 columns]

# %%
df_T1=df_t.drop(['DECOUPZONE', 'ZONENAME', 'REGION','AREA'], axis=1)
df_T1
# Out:
#         CITIES STATUS     LOCALS  LONGITUDE  LATITUDE     CELL_ID     SITE_ID
# 0       ADJAME      1    ABIDJAN  -4.000667  5.368194  fbb2e75af3  0bb492ef17
# 1       ADJAME      1    ABIDJAN  -4.000667  5.368194  1502501d78  0bb492ef17
# 2       ADJAME      1    ABIDJAN  -4.000667  5.368194  0c2e182a0c  0bb492ef17
# 3      ASSINIE      1  INTERIEUR  -3.488467  5.158761  69bdfc69fd  8a1e6ce31f
# 4      ASSINIE      1  INTERIEUR  -3.488467  5.158761  7a1029d2ab  8a1e6ce31f
# ...        ...    ...        ...        ...       ...         ...         ...
# 3969  ZUENOULA      1  INTERIEUR  -6.039694  7.428611  1cfc2d7ab1  f91ed8d2e9
# 3970  ZUENOULA      1  INTERIEUR  -6.039694  7.428611  3ae1708153  f91ed8d2e9
# 3971  ZUENOULA      1  INTERIEUR  -6.065450  7.444592  cb71f8a29c  61bee9c70c
# 3972  ZUENOULA      1  INTERIEUR  -6.065450  7.444592  d4a6a0b645  61bee9c70c
# 3973  ZUENOULA      1  INTERIEUR  -6.065450  7.444592  f9f3e42589  61bee9c70c
#
# [3974 rows x 7 columns]

# %% [markdown]
# #3.2 merging the customers table and cell_sites tables

# %%
#the other ubiquitous operation related to DataFrames is the merging operation.
# Two DataFrames might hold different kinds of information about the same entity and linked by some common feature/column. 
#To join these DataFrames, pandas provides us with function merge()
#In this section, you will practice using merge() function of pandas.
#we will merge the df_piece ....the concated pieces withe cells_sites table to get one which we can clean and use for our analysis
#The FULL OUTER JOIN combines the results of both the left and the right outer joins. 
#The joined DataFrame will contain all records from both the DataFrames and fill in NaNs for missing matches on either side.
df_merge= pd.merge(df_4D, df_T1, left_on='CELL_ID', right_on='CELL_ID',how='outer')
df_merge
# Out:
#       PRODUCT  VALUE               DATETIME  ... LONGITUDE  LATITUDE   SITE_ID_y
# 0           1    0.0  2012-05-06 23:04:37.0  ...       NaN       NaN         NaN
# 1           2    0.0  2012-05-06 23:40:48.0  ...       NaN       NaN         NaN
# 2           2    0.0  2012-05-07 23:32:47.0  ...       NaN       NaN         NaN
# 3           2    0.0  2012-05-07 23:52:21.0  ...       NaN       NaN         NaN
# 4        data    0.0  2012-05-07 23:53:21.0  ...       NaN       NaN         NaN
# ...       ...    ...                    ...  ...       ...       ...         ...
# 18972     NaN    NaN                    NaN  ... -6.039694  7.428611  f91ed8d2e9
# 18973     NaN    NaN                    NaN  ... -6.039694  7.428611  f91ed8d2e9
# 18974     NaN    NaN                    NaN  ... -6.065450  7.444592  61bee9c70c
# 18975     NaN    NaN                    NaN  ... -6.065450  7.444592  61bee9c70c
# 18976     NaN    NaN                    NaN  ... -6.065450  7.444592  61bee9c70c
#
# ...

# %% [markdown]
# #4.0  Cleaning  and  deleting all Irrelevant Information

# %%
#Identify which observations are duplicates from our merged data above
# we will use the.duplicated()function
df_merge.duplicated()

# Drop duplicates
# Uncomment the line below after running previous lines
# df.drop_duplicates()

# Drop duplicates in a specific column
# Uncomment the line below after running previous lines
# df.drop_duplicates(['first_name'], keep='last')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18972    False
# 18973    False
# 18974    False
# 18975    False
# 18976    False
# Length: 18977, dtype: bool

# %%
#Checking in the above results the duplicates we have are of type bool
# we use.isnull()function to know all cells that have Nan VALUE
df_merge.isnull()
# Out:
#        PRODUCT  VALUE  DATETIME  ...  LONGITUDE  LATITUDE  SITE_ID_y
# 0        False  False     False  ...       True      True       True
# 1        False  False     False  ...       True      True       True
# 2        False  False     False  ...       True      True       True
# 3        False  False     False  ...       True      True       True
# 4        False  False     False  ...       True      True       True
# ...        ...    ...       ...  ...        ...       ...        ...
# 18972     True   True      True  ...      False     False      False
# 18973     True   True      True  ...      False     False      False
# 18974     True   True      True  ...      False     False      False
# 18975     True   True      True  ...      False     False      False
# 18976     True   True      True  ...      False     False      False
#
# [18977 rows x 13 columns]

# %%
# We will then Drop all rows where all cells in that row are nan
# we will use th.dropna(fuction)
df_mergecr = df_merge.dropna(how='all')
df_mergecr
# Out:
#       PRODUCT  VALUE               DATETIME  ... LONGITUDE  LATITUDE   SITE_ID_y
# 0           1    0.0  2012-05-06 23:04:37.0  ...       NaN       NaN         NaN
# 1           2    0.0  2012-05-06 23:40:48.0  ...       NaN       NaN         NaN
# 2           2    0.0  2012-05-07 23:32:47.0  ...       NaN       NaN         NaN
# 3           2    0.0  2012-05-07 23:52:21.0  ...       NaN       NaN         NaN
# 4        data    0.0  2012-05-07 23:53:21.0  ...       NaN       NaN         NaN
# ...       ...    ...                    ...  ...       ...       ...         ...
# 18972     NaN    NaN                    NaN  ... -6.039694  7.428611  f91ed8d2e9
# 18973     NaN    NaN                    NaN  ... -6.039694  7.428611  f91ed8d2e9
# 18974     NaN    NaN                    NaN  ... -6.065450  7.444592  61bee9c70c
# 18975     NaN    NaN                    NaN  ... -6.065450  7.444592  61bee9c70c
# 18976     NaN    NaN                    NaN  ... -6.065450  7.444592  61bee9c70c
#
# ...

# %%
# we will also Drop column that also contain only NAN missing values
# We will use the drop.na function but 
df_mergerrt=df_merge.dropna(axis=1, how='all')
df_mergerrt
# Out:
#       PRODUCT  VALUE               DATETIME  ... LONGITUDE  LATITUDE   SITE_ID_y
# 0           1    0.0  2012-05-06 23:04:37.0  ...       NaN       NaN         NaN
# 1           2    0.0  2012-05-06 23:40:48.0  ...       NaN       NaN         NaN
# 2           2    0.0  2012-05-07 23:32:47.0  ...       NaN       NaN         NaN
# 3           2    0.0  2012-05-07 23:52:21.0  ...       NaN       NaN         NaN
# 4        data    0.0  2012-05-07 23:53:21.0  ...       NaN       NaN         NaN
# ...       ...    ...                    ...  ...       ...       ...         ...
# 18972     NaN    NaN                    NaN  ... -6.039694  7.428611  f91ed8d2e9
# 18973     NaN    NaN                    NaN  ... -6.039694  7.428611  f91ed8d2e9
# 18974     NaN    NaN                    NaN  ... -6.065450  7.444592  61bee9c70c
# 18975     NaN    NaN                    NaN  ... -6.065450  7.444592  61bee9c70c
# 18976     NaN    NaN                    NaN  ... -6.065450  7.444592  61bee9c70c
#
# ...

# %% [markdown]
# #4.1 Analysing the data and Conclusions

# %%
#Which cities were the most used during business and home hours?
df_mergerrt.groupby(["CITIES", "PRODUCT"]).size().reset_index(name="sum").sort_values(by="sum", ascending=False)
# Out:
# Empty DataFrame
# Columns: [CITIES, PRODUCT, sum]
# Index: []

# %%
df_mergerrt["DATETIME"] = pd.to_datetime(df_mergerrt['DATETIME'])
df_mergerrt.head()
df_mergerrt.groupby(['CITIES', pd.Grouper(key='DATETIME', freq='M')])['CITIES'].count()
df_mergerrt.
#df_mergerrt.set_index(('DATETIME').resample('M')["CITIES"].sum())
# Out:
#       PRODUCT  VALUE            DATETIME  ... LONGITUDE  LATITUDE   SITE_ID_y
# 0           1    0.0 2012-05-06 23:04:37  ...       NaN       NaN         NaN
# 1           2    0.0 2012-05-06 23:40:48  ...       NaN       NaN         NaN
# 2           2    0.0 2012-05-07 23:32:47  ...       NaN       NaN         NaN
# 3           2    0.0 2012-05-07 23:52:21  ...       NaN       NaN         NaN
# 4        data    0.0 2012-05-07 23:53:21  ...       NaN       NaN         NaN
# ...       ...    ...                 ...  ...       ...       ...         ...
# 18972     NaN    NaN                 NaT  ... -6.039694  7.428611  f91ed8d2e9
# 18973     NaN    NaN                 NaT  ... -6.039694  7.428611  f91ed8d2e9
# 18974     NaN    NaN                 NaT  ... -6.065450  7.444592  61bee9c70c
# 18975     NaN    NaN                 NaT  ... -6.065450  7.444592  61bee9c70c
# 18976     NaN    NaN                 NaT  ... -6.065450  7.444592  61bee9c70c
#
# [18977 rows x 13 columns]

# %%
df_mergerrt.groupby(["CITIES", "STATUS"]).size().reset_index(name="Count").sort_values(by="Count", ascending=False)
#THE MOST USED CITY IS cocody ...COUNT 354
#THE LEAST USED CITIES ARE TWO...OUANGOLO AND DANANON...COUNT1
#THE CITIES KOTOULA IS ALSO LESS USED....COUNT 2
# Out:
#           CITIES STATUS  Count
# 122       COCODY      1    354
# 487     YOPOUGON      1    289
# 1          ABOBO      1    250
# 316      MARCORY      1    141
# 474  TREICHVILLE      1    132
# ..           ...    ...    ...
# 193     GAZIBOUO      1      3
# 325        MEMNI      1      2
# 277      KOTOULA      1      2
# 136      DANANON      1      1
# 369     OUANGOLO      1      1
#
# [503 rows x 3 columns]

# %%
#getting the cities that were used the least
print(df_mergerrt.groupby(['CITIES','STATUS'])['STATUS'].agg(['count'],descending=True))
# Out:
#                       count
# CITIES        STATUS
# ABENGOUROU    1          21
# ABOBO         1         250
# ABOISSO       1          18
# ABOISSO COMOE 1           3
# ABONGOUA      1           3
# ...                     ...
# ZATTA         1           3
# ZIKISSO       1           4
# ZON-HOUNIEN   1           3
# ZOUKOUGBEU    1           3
# ZUENOULA      1           9
#
# [503 rows x 1 columns]

# %%
#From the above analysis we can be able to answer our business problem 
#we have defined for client all the sites that are active and that are oftenly used
#we have also deduced the cities that least used 
#we can be able to make decisive recommendations on behalf of the client

# %% [markdown]
# #5.0 Recommendations based on analysis

# %%
#would advice mtn to focus on the cell sites with lowest activity 
#from that they should send IT department to make sure cell sites are ok
#and since some of these cities we really affected during the elections they could try and replACE or upgrade the cell_sites prioritising the worst
#the best performing sites can do better also
